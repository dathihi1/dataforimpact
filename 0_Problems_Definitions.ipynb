# %% [markdown]
# # Problem Definition: Application of Cohort Analysis and Time Series Forecasting to Optimize Customer Lifetime Value (LTV) and Return on Marketing Investment (ROMI) in E-commerce
#
# ## Introduction
#
# This project utilizes sales transaction data from an e-commerce store (likely a UK-based online retailer) spanning two years: 2009-2010 and 2010-2011. The dataset is stored in an Excel file `online_retail_II.xlsx` with two sheets containing transaction information including invoices, product codes, descriptions, quantities, invoice dates and times, unit prices, customer IDs, and countries.
#
# The primary goal is to apply cohort analysis and time series forecasting techniques to optimize Customer Lifetime Value (LTV) and Return on Marketing Investment (ROMI).
#
# ## Data Description
#
# - **File**: `data/online_retail_II.xlsx`
# - **Sheet 'Year 2009-2010'**: Transaction data from December 2009 to November 2010 (525,461 records)
# - **Sheet 'Year 2010-2011'**: Transaction data from December 2010 to November 2011 (541,910 records)
#
# Data Structure:
# - Invoice: Invoice number
# - StockCode: Product code
# - Description: Product description
# - Quantity: Quantity purchased
# - InvoiceDate: Invoice date and time
# - Price: Unit price
# - Customer ID: Customer identifier
# - Country: Customer's country
#
# ## Problems to Solve
#
# ### 1. Cohort Analysis and LTV Calculation
# - Identify customer cohorts based on first purchase month/year
# - Calculate LTV for each cohort over time
# - Compare purchasing behavior across different cohorts
#
# ### 2. Time Series Forecasting for LTV
# - Build forecasting models for future LTV of new cohorts
# - Predict revenue and customer behavior based on historical trends
#
# ### 3. ROMI Optimization
# - Analyze effectiveness of marketing campaigns
# - Determine optimal marketing spend to achieve maximum ROMI
# - Measure marketing impact on LTV
#
# ### 4. Customer Segmentation
# - Classify customers based on purchasing behavior and LTV
# - Identify high-value and low-value customer groups
#
# ### 5. Churn Prediction and Retention
# - Develop models to predict customer churn rates
# - Create effective customer retention strategies
#
# ## Project Objectives
# - Develop accurate cohort analysis models
# - Implement reliable time series forecasting systems
# - Provide insights for LTV and ROMI optimization
# - Suggest data-driven business strategies

# %%
import pandas as pd

# Load data from Excel file
excel_file = 'data/online_retail_II.xlsx'

# Read both sheets
df1 = pd.read_excel(excel_file, sheet_name='Year 2009-2010', engine='openpyxl')
df2 = pd.read_excel(excel_file, sheet_name='Year 2010-2011', engine='openpyxl')

# Basic info
print('Data 2009-2010 shape:', df1.shape)
print('Data 2010-2011 shape:', df2.shape)
print('\nColumns:', df1.columns.tolist())
print('\nSample data from 2009-2010:')
print(df1.head())
print('\nSample data from 2010-2011:')
print(df2.head())
# Out:
# Data 2009-2010 shape: (525461, 8)
# Data 2010-2011 shape: (541910, 8)
#
# Columns: ['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'Price', 'Customer ID', 'Country']
#
# Sample data from 2009-2010:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom
#
# ...
